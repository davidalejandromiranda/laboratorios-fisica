# %% [markdown]
# Soy yo
# Grupo B1

# %%
print('hola mundo')
# Out:
# hola mundo

# %%
import numpy as np 
import matplotlib.pyplot as plt

x = np.linspace(0,1,1000)
y = np.sin(2*np.pi*x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
