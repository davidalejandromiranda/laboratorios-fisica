# %% [markdown]
# # "Estudio de Ondas Estacionarias en Cuerdas I2"

# %% [markdown]
# ## Relación entre Tensión y Número de Husos

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bibliotecas para importar 
import numpy as np
import matplotlib.pyplot as plt
#Para definir la función
def fun(n):
    f = 60
    mu = 0.00078
    L = 0.8
    funcion = ((((2*L*f)/n)**2))*mu

    return funcion
#Genero rango de valores para n
t1 = np.arange(0.1, 5.0, 0.15)  
#para graficar 
plt.figure()
plt.plot(t1, fun(t1), 'k')

#si quieres quitar los puntos elimina la linea siguiente
plt.plot(t1, fun(t1), 'bo')
#nombre de ejes
plt.ylabel('Tensión [N]')
plt.xlabel('# de Husos')
plt.show()

# %% [markdown]
# ## Relación entre Velocidad y Tensión

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bibliotecas para importar 
import numpy as np
#Para definir la función
def fun(T):
    
    mu = 0.00078
    m = np.arange(0.1, 5.0, 0.15)
    T = 9.8*m
    funcion = ((T/mu)**(1/2))

    return funcion

#para graficar 
plt.figure()
plt.plot(t1, fun(t1), 'k')

#si quieres quitar los puntos elimina la linea siguiente
plt.plot(t1, fun(t1), 'bo')
#nombre de ejes
plt.ylabel('Velocidad [m/s]')
plt.xlabel('Tensión [N]')
plt.show()

# %% [markdown]
# ## Relación entre Longitud de Onda y Tensión

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#bibliotecas para importar 
import numpy as np
#definir la función
def fun(T):
    f = 60
    mu = 0.00078
    m = np.arange(0.1, 5.0, 0.15)
    T = 9.8*m
    funcion = ((1/f)*(T/mu)**(1/2))

    return funcion

#para graficar
plt.figure()
plt.plot(t1, fun(t1), 'k')

#si quieres quitar los puntos elimina la linea siguiente
plt.plot(t1, fun(t1), 'bo')
#nombre de ejes
plt.ylabel('Longitud de Onda')
plt.xlabel('Tensión [N]')
plt.show()

# %% [markdown]
# ##### Grupo B1 Laboratorio de Física 3 GRUPO H2B
